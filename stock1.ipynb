# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn import linear_model

# %%
import matplotlib.pyplot

# %%
df=pd.read_csv("C:\\Users\\Admin\\Downloads\\LT.NS.csv")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df.Date, df.Open, marker="*")

# %%
reg=linear_model.LinearRegression()

# %%
from datetime import datetime  # Import the datetime class from the datetime module

df['Date'] = df['Date'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y').timestamp())
reg.fit(df[['Date']], df.Open)
# Out:
# LinearRegression()

# %% [markdown]
# # Assistant
# The error is occurring because the 'Date' column contains string values that cannot be directly converted to float for the regression model.
#
# To fix this error, you need to convert the date strings to a numerical format that the regression model can understand, such as a timestamp or a numerical representation of the date.
#
# Would you like me to provide the corrected code?

# %% [markdown]
# # Assistant
# The error is occurring because the `fit` method is expecting numeric input data, but it is receiving a list of strings instead.
#
# To fix this error, you need to provide numeric input data to the `fit` method.
#
# Would you like me to provide the corrected code? yes

# %%
reg.predict([[1722495600]])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3838.05301191])
